# %%
'''
@Time : 2023-10-09 16:42
@Author : laolao
@FileName: model_test.py
'''

import pickle
import html

def predict(my_code,v, w):
    X_predict = v.transform(my_code)
    res = w.predict(X_predict)
    res_list = []

    for q, r in zip(my_code, res):
        tmp = '正常请求' if r == 0 else '恶意请求'
        res_list.append({'url': q, 'res': tmp})

    import pandas as pd

    df = pd.DataFrame(res_list)
    print("恶意请求：")
    print(df.loc[df['res'] == '恶意请求'].count())
    print("正常请求：")
    print(df.loc[df['res'] == '正常请求'].count())
    df.to_csv("output.csv")
    return df

# %% [markdown]
# # 只用good和bad训练出来的

# %%
with open('file/logs.pkl', 'rb') as input:
    v, w = pickle.load(input)

with open("data/nsfocus_isop_text.txt", "r", encoding='utf-8') as f:
    my_code = f.readlines()

predict(my_code,v, w)
# Out:
# 恶意请求：
# url    16
# res    16
# dtype: int64
# 正常请求：
# url    82
# res    82
# dtype: int64
#                                                   url   res
# 0   GET/CFIDE/administrator/logging/settings.cfm?l...  恶意请求
# 1                :Xj+V3jpv#{:8PGET/?q=${${::-j}ndi:\n  正常请求
# 2   :PVE@"UZ=Z=<10e0--mzhJAZYARYrQDQLaF0zPG6ucYuC1...  恶意请求
# 3   POST/solr/techproducts/configCookie:JSESSIONID...  正常请求
# 4   GET/login.do?a=${#_memberAccess["allowStaticMe...  正常请求
# ..                                                ...   ...
# 93  GET/seeyon/thirdpartyController.do.css/..;/aja...  正常请求
# 94  POST/sys/ui/extend/varkind/custom.jspvar={"bod...  正常请求
# 95  :PV2@5apse#POST/maintence.phpX-Real-IP:172.25....  正常请求
# 96  POST/ispirit/interface/gateway.phpSec-Fetch-De...  正常请求
# 97  POST/ispirit/interface/gateway.phpRange:bytes=...  正常请求
#
# [98 rows x 2 columns]

# %% [markdown]
# # 加了isop的数据训练出来的

# %%
with open('file/logs_add_isop.pkl', 'rb') as input:
    v, w = pickle.load(input)

with open("data/nsfocus_isop_text.txt", "r", encoding='utf-8') as f:
    my_code = f.readlines()
predict(my_code,v, w)
# Out:
# 恶意请求：
# url    0
# res    0
# dtype: int64
# 正常请求：
# url    98
# res    98
# dtype: int64
#                                                   url   res
# 0   GET/CFIDE/administrator/logging/settings.cfm?l...  正常请求
# 1                :Xj+V3jpv#{:8PGET/?q=${${::-j}ndi:\n  正常请求
# 2   :PVE@"UZ=Z=<10e0--mzhJAZYARYrQDQLaF0zPG6ucYuC1...  正常请求
# 3   POST/solr/techproducts/configCookie:JSESSIONID...  正常请求
# 4   GET/login.do?a=${#_memberAccess["allowStaticMe...  正常请求
# ..                                                ...   ...
# 93  GET/seeyon/thirdpartyController.do.css/..;/aja...  正常请求
# 94  POST/sys/ui/extend/varkind/custom.jspvar={"bod...  正常请求
# 95  :PV2@5apse#POST/maintence.phpX-Real-IP:172.25....  正常请求
# 96  POST/ispirit/interface/gateway.phpSec-Fetch-De...  正常请求
# 97  POST/ispirit/interface/gateway.phpRange:bytes=...  正常请求
#
# [98 rows x 2 columns]

# %%
with open("data/goodqueries.txt", "r", encoding='utf-8') as f:
    my_code = f.readlines()
predict(my_code,v, w)
# Out:
# 恶意请求：
# url    0
# res    0
# dtype: int64
# 正常请求：
# url    1294531
# res    1294531
# dtype: int64
#                                   url   res
# 0                          /103886/\n  正常请求
# 1                        /rcanimal/\n  正常请求
# 2                   /458010b88d9ce/\n  正常请求
# 3                        /cclogovs/\n  正常请求
# 4              /using-localization/\n  正常请求
# ...                               ...   ...
# 1294526                    /197573/\n  正常请求
# 1294527  /javascript/management.php\n  正常请求
# 1294528   /javascript/minute.csproj\n  正常请求
# 1294529                    /tex-lg/\n  正常请求
# 1294530       /javascript/42.tar.gz\n  正常请求
#
# [1294531 rows x 2 columns]

# %%
with open("data/nsfocus_isop.txt", "r", encoding='utf-8') as f:
    my_code = f.readlines()
predict(my_code,v, w)
# Out:
# 恶意请求：
# url    0
# res    0
# dtype: int64
# 正常请求：
# url    70
# res    70
# dtype: int64
#                                                   url   res
# 0   Xj[EtdF4vo>v!Ph]pH@POST/GponForm/diag_Form?ima...  正常请求
# 1   XjEQ@`^PPPOST/FCKeditor/editor/filemanager/con...  正常请求
# 2   (.Z9hH|@<P5Ptom=@eval(base64_decode($_POST[z0]...  正常请求
# 3                                             3.1.2\n  正常请求
# 4   a]PVXj&Eozr@@KiMGET/seeyon/personalBind.do.jpg...  正常请求
# ..                                                ...   ...
# 65  Xj+(9jpb%]QKPGET/zjkbank/uiFramework/huilan-jq...  正常请求
# 66  aK<XjAXj&*@AQPGET/secure/ViewUserHover.jspa?us...  正常请求
# 67  ajfXjAXj&Tx@CQ5C<GET/wxjsapi/saveYZJFile?fileN...  正常请求
# 68  GET/tool/log/c.php?strip_slashes=printf&host=c...  正常请求
# 69  POST/index.aspCharset=UTF-8X-Forwarded-For:219...  正常请求
#
# [70 rows x 2 columns]

# %%
with open("data/badqueries.txt", "r", encoding='utf-8') as f:
    my_code = f.readlines()
predict(my_code,v, w)
# Out:
# 恶意请求：
# url    0
# res    0
# dtype: int64
# 正常请求：
# url    48126
# res    48126
# dtype: int64
#                                                      url   res
# 0                   /top.php?stuff='uname >q36497765 #\n  正常请求
# 1      /h21y8w52.nsf?<script>cross_site_scripting.nas...  正常请求
# 2      /ca000001.pl?action=showcart&hop=\"><script>al...  正常请求
# 3      /scripts/edit_image.php?dn=1&userfile=/etc/pas...  正常请求
# 4                                  /javascript/mta.exe\n  正常请求
# ...                                                  ...   ...
# 48121        "text </script><script>alert(1)</script>"\n  正常请求
# 48122  <marquee loop=1 width=0 onfinish=1/confirm`/1/...  正常请求
# 48123  <marquee loop=1 width=0 onfinish=confirm(1)>0<...  正常请求
# 48124  <abeon style=font-size:12px onmouseover=confir...  正常请求
# 48125                  <svg onload=location='//p0.al'>\n  正常请求
#
# [48126 rows x 2 columns]

# %% [markdown]
# # 将isop与bad合并训练出来的

# %%
with open('file/logs.pkl', 'rb') as input:
    v, w = pickle.load(input)
    
with open("data/badqueries.txt", "r", encoding='utf-8') as f:
    my_code = f.readlines()
predict(my_code,v, w)
# Out:
# 恶意请求：
# url    40394
# res    40394
# dtype: int64
# 正常请求：
# url    7732
# res    7732
# dtype: int64
#                                                      url   res
# 0                   /top.php?stuff='uname >q36497765 #\n  恶意请求
# 1      /h21y8w52.nsf?<script>cross_site_scripting.nas...  恶意请求
# 2      /ca000001.pl?action=showcart&hop=\"><script>al...  恶意请求
# 3      /scripts/edit_image.php?dn=1&userfile=/etc/pas...  恶意请求
# 4                                  /javascript/mta.exe\n  恶意请求
# ...                                                  ...   ...
# 48121        "text </script><script>alert(1)</script>"\n  恶意请求
# 48122  <marquee loop=1 width=0 onfinish=1/confirm`/1/...  正常请求
# 48123  <marquee loop=1 width=0 onfinish=confirm(1)>0<...  恶意请求
# 48124  <abeon style=font-size:12px onmouseover=confir...  恶意请求
# 48125                  <svg onload=location='//p0.al'>\n  恶意请求
#
# [48126 rows x 2 columns]

# %%
with open("data/nsfocus_isop.txt", "r", encoding='utf-8') as f:
    my_code = f.readlines()
predict(my_code,v, w)
# Out:
# 恶意请求：
# url    14
# res    14
# dtype: int64
# 正常请求：
# url    56
# res    56
# dtype: int64
#                                                   url   res
# 0   Xj[EtdF4vo>v!Ph]pH@POST/GponForm/diag_Form?ima...  正常请求
# 1   XjEQ@`^PPPOST/FCKeditor/editor/filemanager/con...  正常请求
# 2   (.Z9hH|@<P5Ptom=@eval(base64_decode($_POST[z0]...  正常请求
# 3                                             3.1.2\n  正常请求
# 4   a]PVXj&Eozr@@KiMGET/seeyon/personalBind.do.jpg...  正常请求
# ..                                                ...   ...
# 65  Xj+(9jpb%]QKPGET/zjkbank/uiFramework/huilan-jq...  正常请求
# 66  aK<XjAXj&*@AQPGET/secure/ViewUserHover.jspa?us...  正常请求
# 67  ajfXjAXj&Tx@CQ5C<GET/wxjsapi/saveYZJFile?fileN...  正常请求
# 68  GET/tool/log/c.php?strip_slashes=printf&host=c...  正常请求
# 69  POST/index.aspCharset=UTF-8X-Forwarded-For:219...  正常请求
#
# [70 rows x 2 columns]

# %%
with open("data/nsfocus_isop_text.txt", "r", encoding='utf-8') as f:
    my_code = f.readlines()
predict(my_code,v, w)
# Out:
# 恶意请求：
# url    21
# res    21
# dtype: int64
# 正常请求：
# url    77
# res    77
# dtype: int64
#                                                   url   res
# 0   GET/CFIDE/administrator/logging/settings.cfm?l...  恶意请求
# 1                :Xj+V3jpv#{:8PGET/?q=${${::-j}ndi:\n  正常请求
# 2   :PVE@"UZ=Z=<10e0--mzhJAZYARYrQDQLaF0zPG6ucYuC1...  恶意请求
# 3   POST/solr/techproducts/configCookie:JSESSIONID...  正常请求
# 4   GET/login.do?a=${#_memberAccess["allowStaticMe...  正常请求
# ..                                                ...   ...
# 93  GET/seeyon/thirdpartyController.do.css/..;/aja...  正常请求
# 94  POST/sys/ui/extend/varkind/custom.jspvar={"bod...  正常请求
# 95  :PV2@5apse#POST/maintence.phpX-Real-IP:172.25....  正常请求
# 96  POST/ispirit/interface/gateway.phpSec-Fetch-De...  正常请求
# 97  POST/ispirit/interface/gateway.phpRange:bytes=...  正常请求
#
# [98 rows x 2 columns]

# %%
with open("data/goodqueries.txt", "r", encoding='utf-8') as f:
    my_code = f.readlines()
predict(my_code,v, w)
# Out:
# 恶意请求：
# url    122
# res    122
# dtype: int64
# 正常请求：
# url    1294409
# res    1294409
# dtype: int64
#                                   url   res
# 0                          /103886/\n  正常请求
# 1                        /rcanimal/\n  正常请求
# 2                   /458010b88d9ce/\n  正常请求
# 3                        /cclogovs/\n  正常请求
# 4              /using-localization/\n  正常请求
# ...                               ...   ...
# 1294526                    /197573/\n  正常请求
# 1294527  /javascript/management.php\n  正常请求
# 1294528   /javascript/minute.csproj\n  正常请求
# 1294529                    /tex-lg/\n  正常请求
# 1294530       /javascript/42.tar.gz\n  正常请求
#
# [1294531 rows x 2 columns]
